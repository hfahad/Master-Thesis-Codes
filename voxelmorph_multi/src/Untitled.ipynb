# %%
import SimpleITK as sitk
import matplotlib.pyplot as plt

# %%
a=sitk.GetArrayFromImage(sitk.ReadImage('data/700005_HELENA_20150527_11_3D_GRE_TRA_HELENA_W.nrrd'))

# %%
a.shape
# Out:
# (96, 176, 256)

# %%
plt.imshow(a[:,:,100],'gray')
